# %% [markdown]
# <a href="https://colab.research.google.com/github/sakasa/AttendanceChatPost-ChromeExtension/blob/master/tokyo_covid19_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from pytz import timezone
import numpy as np
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Tokyo COVID19 Data
# https://github.com/tokyo-metropolitan-gov/covid19

# %%
url = 'https://raw.githubusercontent.com/tokyo-metropolitan-gov/covid19/development/data/data.json'

# %%
response = requests.get(url)
print(response)
j_res = json.loads(response.text) # json文字列をdictへ
print(j_res.keys())
j_res['patients_summary']['data'][-15:]
# Out:
# <Response [200]>
# dict_keys(['contacts', 'querents', 'patients_summary', 'inspections_summary', 'lastUpdate', 'main_summary'])
# [{'小計': 1026, '日付': '2021-01-26T08:00:00.000Z'},
#  {'小計': 973, '日付': '2021-01-27T08:00:00.000Z'},
#  {'小計': 1064, '日付': '2021-01-28T08:00:00.000Z'},
#  {'小計': 868, '日付': '2021-01-29T08:00:00.000Z'},
#  {'小計': 769, '日付': '2021-01-30T08:00:00.000Z'},
#  {'小計': 633, '日付': '2021-01-31T08:00:00.000Z'},
#  {'小計': 393, '日付': '2021-02-01T08:00:00.000Z'},
#  {'小計': 556, '日付': '2021-02-02T08:00:00.000Z'},
#  {'小計': 676, '日付': '2021-02-03T08:00:00.000Z'},
#  {'小計': 734, '日付': '2021-02-04T08:00:00.000Z'},
#  {'小計': 577, '日付': '2021-02-05T08:00:00.000Z'},
#  {'小計': 639, '日付': '2021-02-06T08:00:00.000Z'},
#  {'小計': 429, '日付': '2021-02-07T08:00:00.000Z'},
#  {'小計': 276, '日付': '2021-02-08T08:00:00.000Z'},
#  {'小計': 412, '日付': '2021-02-09T08:00:00.000Z'}]

# %%
def utc_datestr_to_jst_date(datestr):
  #return datetime.datetime.fromisoformat(datestr.replace('Z', '+00:00')).astimezone(timezone('Asia/Tokyo'))
  # for ~Python3.6
  return datetime.datetime.strptime(datestr.split('.')[0].replace('-', '').replace(':', ''), '%Y%m%dT%H%M%S').astimezone(timezone('Asia/Tokyo'))

# %%
keys = ['contacts', 'querents', 'patients_summary']

# %%
d = j_res
df = pd.DataFrame()
for key in keys:
  k = f'{key.split("_")[0]}_count'
  for v in d[key].values():
    if type(v) is list:
      index = [_v['日付'] for _v in v]
      tmp_df = pd.DataFrame(_v for _v in v)
      tmp_df.index = [utc_datestr_to_jst_date(dt) for dt in tmp_df['日付']]
      tmp_df[k] = tmp_df['小計']
  df = pd.concat([df, tmp_df[k]], axis=1)
df = df.fillna(0).astype('int64')
df.index = [i for i in df.index]
df['datetime'] = df.index
df
# Out:
#                            contacts_count  ...                  datetime
# 2020-01-24 17:00:00+09:00               0  ... 2020-01-24 17:00:00+09:00
# 2020-01-25 17:00:00+09:00               0  ... 2020-01-25 17:00:00+09:00
# 2020-01-26 17:00:00+09:00               0  ... 2020-01-26 17:00:00+09:00
# 2020-01-27 17:00:00+09:00               0  ... 2020-01-27 17:00:00+09:00
# 2020-01-28 17:00:00+09:00               0  ... 2020-01-28 17:00:00+09:00
# ...                                   ...  ...                       ...
# 2021-02-05 17:00:00+09:00             335  ... 2021-02-05 17:00:00+09:00
# 2021-02-06 17:00:00+09:00             374  ... 2021-02-06 17:00:00+09:00
# 2021-02-07 17:00:00+09:00             291  ... 2021-02-07 17:00:00+09:00
# 2021-02-08 17:00:00+09:00             332  ... 2021-02-08 17:00:00+09:00
# 2021-02-09 17:00:00+09:00               0  ... 2021-02-09 17:00:00+09:00
#
# [383 rows x 4 columns]

# %%
# 7日移動平均
df1 = df
for key in keys:
  k = key.split('_')[0]
  df1[f'{k}_7d_mov_ave'] = df[f'{k}_count'].rolling('7D').mean()
  # df1[f'{k}_7d_mov_center_ave'] = df[f'{k}_count'].rolling(7, center=True).mean()
  df1[f'{k}_7d_mov_sum'] = df[f'{k}_count'].rolling('7D').sum()
df1.tail()
# Out:
#                            contacts_count  ...  patients_7d_mov_sum
# 2021-02-05 17:00:00+09:00             335  ...               4338.0
# 2021-02-06 17:00:00+09:00             374  ...               4208.0
# 2021-02-07 17:00:00+09:00             291  ...               4004.0
# 2021-02-08 17:00:00+09:00             332  ...               3887.0
# 2021-02-09 17:00:00+09:00               0  ...               3743.0
#
# [5 rows x 10 columns]

# %%
df2 = df1
# 日付が年の何週目かを列にセット `'{yy}w{week nnum}`
df2['week_num'] = [f'\'{d.strftime("%y")}w{d.strftime("%V")}' for d in df1.index]
# 曜日の列をセット
df2['week_day'] = [d.strftime('%a') for d in df1.index]
df2.tail(15)
# Out:
#                            contacts_count  querents_count  ...  week_num week_day
# 2021-01-26 17:00:00+09:00             511               0  ...    '21w04      Tue
# 2021-01-27 17:00:00+09:00             515               0  ...    '21w04      Wed
# 2021-01-28 17:00:00+09:00             454               0  ...    '21w04      Thu
# 2021-01-29 17:00:00+09:00             401               0  ...    '21w04      Fri
# 2021-01-30 17:00:00+09:00             445               0  ...    '21w04      Sat
# 2021-01-31 17:00:00+09:00             404               0  ...    '21w04      Sun
# 2021-02-01 17:00:00+09:00             432               0  ...    '21w05      Mon
# 2021-02-02 17:00:00+09:00             369               0  ...    '21w05      Tue
# 2021-02-03 17:00:00+09:00             337               0  ...    '21w05      Wed
# 2021-02-04 17:00:00+09:00             331               0  ...    '21w05      Thu
# 2021-02-05 17:00:00+09:00             335               0  ...    '21w05      Fri
# 2021-02-06 17:00:00+09:00             374               0  ...    '21w05      Sat
# 2021-02-07 17:00:00+09:00             291               0  ...    '21w05      Sun
# 2021-02-08 17:00:00+09:00             332               0  ...    '21w06      Mon
# 2021-02-09 17:00:00+09:00               0               0  ...    '21w06      Tue
#
# [15 rows x 12 columns]

# %%
# 週毎に集計
groupby_week_num = df2.groupby('week_num', as_index=True)

# %%
# 集計結果から平均と合計を取得しデータフレームにセット
patients_week_num_df = pd.DataFrame({
    # 'patients_week_num': df2['week_num'].unique(),
    'patients_week_mean': [m for m in groupby_week_num.agg({'patients_count': 'mean'})['patients_count']], 
    'patients_week_sum': [s for s in groupby_week_num.agg({'patients_count': 'sum'})['patients_count']]
  }, index=[d for d in groupby_week_num.agg({'datetime': 'max'})['datetime']])
patients_week_num_df.tail()
# Out:
#                            patients_week_mean  patients_week_sum
# 2021-01-24 17:00:00+09:00         1202.857143               8420
# 2021-01-31 17:00:00+09:00          850.142857               5951
# 2021-02-07 17:00:00+09:00          572.000000               4004
# 2021-02-09 17:00:00+09:00          344.000000                688
# 2021-01-03 17:00:00+09:00          804.333333               2413

# %%
df3 = pd.concat([
                df2,
                patients_week_num_df.loc[:, ['patients_week_mean', 'patients_week_sum']]
                ], axis=1)
df3.tail(15)
# Out:
#                            contacts_count  ...  patients_week_sum
# 2021-01-26 17:00:00+09:00             511  ...                NaN
# 2021-01-27 17:00:00+09:00             515  ...                NaN
# 2021-01-28 17:00:00+09:00             454  ...                NaN
# 2021-01-29 17:00:00+09:00             401  ...                NaN
# 2021-01-30 17:00:00+09:00             445  ...                NaN
# 2021-01-31 17:00:00+09:00             404  ...             5951.0
# 2021-02-01 17:00:00+09:00             432  ...                NaN
# 2021-02-02 17:00:00+09:00             369  ...                NaN
# 2021-02-03 17:00:00+09:00             337  ...                NaN
# 2021-02-04 17:00:00+09:00             331  ...                NaN
# 2021-02-05 17:00:00+09:00             335  ...                NaN
# 2021-02-06 17:00:00+09:00             374  ...                NaN
# 2021-02-07 17:00:00+09:00             291  ...             4004.0
# 2021-02-08 17:00:00+09:00             332  ...                NaN
# 2021-02-09 17:00:00+09:00               0  ...              688.0
#
# [15 rows x 14 columns]

# %% [markdown]
# ### グラフ出力

# %%
### 日毎の数
x = df3.index
y1_1 = df3['patients_count']
y1_2 = df3['patients_7d_mov_ave']
#y1_3 = df3['patients_7d_mov_center_ave']
y1_4 = df3['patients_week_mean']

# %%
### 週毎の数
y2_1 = df3['patients_7d_mov_sum']
y2_2 = df3['patients_week_sum']

# %%
fig, ax = plt.subplots(2, 1, figsize=(20, 14))

### 日毎の数
ax[0].set_title('daily count')
ax[0].set_xlabel('date')
ax[0].set_ylabel('sum')
ax[0].bar(x, y1_1, label='patients_count')
ax[0].plot(x, y1_2, label='patients_7d_mov_ave')
#ax[0].plot(x, y1_3, label='patients_7d_mov_center_ave')
# ax[0].bar(x, y1_4, label='patients_week_mean')
ax[0].grid(linestyle=':')
ax[0].legend()

### 週毎の合計
ax[1].set_title('weekly count')
ax[1].set_xlabel('date')
ax[1].set_ylabel('sum')
ax[1].plot(x, y2_1, label='patients_7d_mov_sum')
ax[1].bar(x, y2_2, label='patients_week_sum')
ax[1].grid(linestyle=':')
ax[1].legend()

plt.tight_layout()

# %% [markdown]
# ---

# %%
def get_date(d: datetime) -> datetime:
  """時間が入った `datetime` を `%Y-%m-%d 00:00:00` の `datetime` に変換します"""
  return datetime.datetime.strptime(d.strftime('%Y-%m-%d'), '%Y-%m-%d')

# %%
em_start = datetime.datetime(2020, 4, 7)
em_end = datetime.datetime(2020, 5, 25)
def em_term() -> list:
  """緊急事態宣言期間の日付のリスト"""
  em_term = []
  for i in range((em_end - em_start).days + 1):
    em_term.append(em_start + datetime.timedelta(i))
  return em_term

# %%
def emergency(d: datetime) -> int:
  """緊急事態宣言期間中か"""
  return int(get_date(d) in em_term())

# %%
def em_passed(d: datetime) -> int:
  """緊急事態宣言から経過日数"""
  d = get_date(d)
  return (d - em_start).days if em_start < d else 0

# %%
ds_df = pd.DataFrame({
    'timestamp': [d.timestamp() for d in df3.index], # タイムスタンプ
    'year': np.array(df3.index.strftime('%Y'), dtype=np.int64), # 年
    'month': np.array(df3.index.strftime('%m'), dtype=np.int64), # 月
    'day': np.array(df3.index.strftime('%d'), dtype=np.int64), # 日
    'week_day': df3['week_day'], # 曜日
})
# 曜日をダミー変数化
ds_df = pd.concat([ds_df, pd.get_dummies(ds_df['week_day'])], axis=1)
ds_df = ds_df.drop(columns=['week_day'])

# 経過日数
# ds_df['passed'] = [(d - df3['datetime'][0]).days for d in df3['datetime']]
ds_df['passed'] = [(d - df3.index[0]).days for d in df3.index]
# 緊急事態宣言期間中
ds_df['emergency'] = [emergency(d) for d in df3.index]
# 緊急事態宣言経過日数
ds_df['em_passed'] = [em_passed(d) for d in df3.index]
for key in keys:
  k = key.split('_')[0]
  # 日毎の数
  ds_df[f'{k}_count'] = df3[f'{k}_count']
  # 7日間移動平均
  ds_df[f'{k}_7d_mov_ave'] = df3[f'{k}_7d_mov_ave']
  #ds_df[f'{k}_7d_mov_center_ave'] = df3[f'{k}_7d_mov_center_ave']
  # 7日間移動合計
  ds_df[f'{k}_7d_mov_sum'] = df3[f'{k}_7d_mov_sum']

# 日毎の数
# ds_df['patients_count'] = df3['patients_count']
# 7日間移動平均
# ds_df['patients_7d_mov_ave'] = df3['patients_7d_mov_ave']
#ds_df['7d_mov_center_ave'] = df3['patients_7d_mov_center_ave']
# 7日間移動合計
# ds_df['patients_7d_mov_sum'] = df3['patients_7d_mov_sum']

ds_df = ds_df.reset_index(drop=True)
ds_df.tail(15)
# Out:
#         timestamp  year  ...  patients_7d_mov_ave  patients_7d_mov_sum
# 368  1.611648e+09  2021  ...          1088.571429               7620.0
# 369  1.611734e+09  2021  ...          1045.571429               7319.0
# 370  1.611821e+09  2021  ...           987.428571               6912.0
# 371  1.611907e+09  2021  ...           943.571429               6605.0
# 372  1.611994e+09  2021  ...           900.571429               6304.0
# 373  1.612080e+09  2021  ...           850.142857               5951.0
# 374  1.612166e+09  2021  ...           818.000000               5726.0
# 375  1.612253e+09  2021  ...           750.857143               5256.0
# 376  1.612339e+09  2021  ...           708.428571               4959.0
# 377  1.612426e+09  2021  ...           661.285714               4629.0
# 378  1.612512e+09  2021  ...           619.714286               4338.0
# 379  1.612598e+09  2021  ...           601.142857               4208.0
# 380  1.612685e+09  2021  ...           572.000000               4004.0
# 381  1.612771e+09  2021  ...           555.285714               3887.0
# 382  1.612858e+09  2021  ...           534.714286               3743.0
#
# [15 rows x 23 columns]

# %%
ds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            383 non-null    float64
#  1   year                 383 non-null    int64
#  2   month                383 non-null    int64
#  3   day                  383 non-null    int64
#  4   Fri                  383 non-null    uint8
#  5   Mon                  383 non-null    uint8
#  6   Sat                  383 non-null    uint8
#  7   Sun                  383 non-null    uint8
#  8   Thu                  383 non-null    uint8
#  9   Tue                  383 non-null    uint8
#  10  Wed                  383 non-null    uint8
#  11  passed               383 non-null    int64
#  12  emergency            383 non-null    int64
#  13  em_passed            383 non-null    int64
#  14  contacts_count       383 non-null    int64
#  15  contacts_7d_mov_ave  383 non-null    float64
#  16  contacts_7d_mov_sum  383 non-null    float64
#  17  querents_count       383 non-null    int64
#  18  querents_7d_mov_ave  383 non-null    float64
#  19  querents_7d_mov_sum  383 non-null    float64
#  20  patients_count       383 non-null    int64
#  21  patients_7d_mov_ave  383 non-null    float64
#  22  patients_7d_mov_sum  383 non-null    float64
# dtypes: float64(7), int64(9), uint8(7)
# memory usage: 50.6 KB

# %%
ds_df.describe()
# Out:
#           timestamp         year  ...  patients_7d_mov_ave  patients_7d_mov_sum
# count  3.830000e+02   383.000000  ...           383.000000           383.000000
# mean   1.596355e+09  2020.104439  ...           269.442111          1886.052219
# std    9.565069e+06     0.306229  ...           363.657759          2545.635862
# min    1.579853e+09  2020.000000  ...             0.000000             0.000000
# 25%    1.588104e+09  2020.000000  ...            25.071429           175.500000
# 50%    1.596355e+09  2020.000000  ...           163.428571          1144.000000
# 75%    1.604606e+09  2020.000000  ...           311.000000          2177.000000
# max    1.612858e+09  2021.000000  ...          1812.714286         12689.000000
#
# [8 rows x 23 columns]

# %%
ds_df.corr()
# Out:
#                         timestamp  ...  patients_7d_mov_sum
# timestamp            1.000000e+00  ...             0.731917
# year                 5.297127e-01  ...             0.824922
# month                4.759755e-01  ...            -0.107531
# day                 -6.043875e-03  ...             0.002845
# Fri                 -7.407433e-03  ...            -0.002799
# Mon                  3.703717e-03  ...             0.001137
# Sat                 -3.703717e-03  ...            -0.000928
# Sun                 -7.258744e-19  ...             0.000328
# Thu                  1.832155e-03  ...             0.001042
# Tue                  7.407433e-03  ...             0.002343
# Wed                 -1.832155e-03  ...            -0.001124
# passed               1.000000e+00  ...             0.731917
# emergency           -3.221819e-01  ...            -0.191112
# em_passed            9.906610e-01  ...             0.751649
# contacts_count      -8.140535e-02  ...             0.128430
# contacts_7d_mov_ave -4.548765e-02  ...             0.170647
# contacts_7d_mov_sum -4.548199e-02  ...             0.170648
# querents_count      -3.153816e-01  ...            -0.391510
# querents_7d_mov_ave -3.300458e-01  ...            -0.440649
# querents_7d_mov_sum -3.300458e-01  ...            -0.440649
# patients_count       6.910472e-01  ...             0.932488
# patients_7d_mov_ave  7.318969e-01  ...             1.000000
# patients_7d_mov_sum  7.319166e-01  ...             1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# ---

# %%
ds_df.columns
# Out:
# Index(['timestamp', 'year', 'month', 'day', 'Fri', 'Mon', 'Sat', 'Sun', 'Thu',
#        'Tue', 'Wed', 'passed', 'emergency', 'em_passed', 'contacts_count',
#        'contacts_7d_mov_ave', 'contacts_7d_mov_sum', 'querents_count',
#        'querents_7d_mov_ave', 'querents_7d_mov_sum', 'patients_count',
#        'patients_7d_mov_ave', 'patients_7d_mov_sum'],
#       dtype='object')

# %%
_df = ds_df.copy()
_df = _df.drop(['year', 'month', 'day', 
          'contacts_7d_mov_ave', 'contacts_7d_mov_sum', 
          'querents_7d_mov_ave', 'querents_7d_mov_sum', 
          ], axis=1)
_df
# Out:
#         timestamp  Fri  ...  patients_7d_mov_ave  patients_7d_mov_sum
# 0    1.579853e+09    1  ...             1.000000                  1.0
# 1    1.579939e+09    0  ...             1.000000                  2.0
# 2    1.580026e+09    0  ...             0.666667                  2.0
# 3    1.580112e+09    0  ...             0.500000                  2.0
# 4    1.580198e+09    0  ...             0.400000                  2.0
# ..            ...  ...  ...                  ...                  ...
# 378  1.612512e+09    1  ...           619.714286               4338.0
# 379  1.612598e+09    0  ...           601.142857               4208.0
# 380  1.612685e+09    0  ...           572.000000               4004.0
# 381  1.612771e+09    0  ...           555.285714               3887.0
# 382  1.612858e+09    0  ...           534.714286               3743.0
#
# [383 rows x 16 columns]

# %%
_df2 = _df[['timestamp', 'passed', 'emergency', 'patients_count', 'patients_7d_mov_ave', 'patients_7d_mov_sum']]
_df2
# Out:
#         timestamp  passed  ...  patients_7d_mov_ave  patients_7d_mov_sum
# 0    1.579853e+09       0  ...             1.000000                  1.0
# 1    1.579939e+09       1  ...             1.000000                  2.0
# 2    1.580026e+09       2  ...             0.666667                  2.0
# 3    1.580112e+09       3  ...             0.500000                  2.0
# 4    1.580198e+09       4  ...             0.400000                  2.0
# ..            ...     ...  ...                  ...                  ...
# 378  1.612512e+09     378  ...           619.714286               4338.0
# 379  1.612598e+09     379  ...           601.142857               4208.0
# 380  1.612685e+09     380  ...           572.000000               4004.0
# 381  1.612771e+09     381  ...           555.285714               3887.0
# 382  1.612858e+09     382  ...           534.714286               3743.0
#
# [383 rows x 6 columns]

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(data=_df)

# %%
sns.pairplot(data=_df2)

# %%
# !python -V
# Out:
# Python 3.6.9
